# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Jairus\anaconda3\python.exe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("OK")
# Out:
# OK

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Jairus\OneDrive\Documents\Portfolio\01.Fraud_Detection_Project\notebooks

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
DATA_DIR = PROJECT_ROOT/"data"
RAW_DIR = DATA_DIR/"raw"
PROCESSED_DIR = DATA_DIR/"processed"
REPORTS_DIR = PROJECT_ROOT/"reports"
MODELS_DIR = PROJECT_ROOT/"models"

print("Project root:",PROJECT_ROOT)
print("Raw data folder:",RAW_DIR)
# Out:
# Project root: C:\Users\Jairus\OneDrive\Documents\Portfolio\01.Fraud_Detection_Project
# Raw data folder: C:\Users\Jairus\OneDrive\Documents\Portfolio\01.Fraud_Detection_Project\data\raw

# %%
for p in [DATA_DIR,RAW_DIR,PROCESSED_DIR,REPORTS_DIR,MODELS_DIR]:
    print(p,"->",p.exists())
# Out:
# C:\Users\Jairus\OneDrive\Documents\Portfolio\01.Fraud_Detection_Project\data -> True
# C:\Users\Jairus\OneDrive\Documents\Portfolio\01.Fraud_Detection_Project\data\raw -> True
# C:\Users\Jairus\OneDrive\Documents\Portfolio\01.Fraud_Detection_Project\data\processed -> True
# C:\Users\Jairus\OneDrive\Documents\Portfolio\01.Fraud_Detection_Project\reports -> True
# C:\Users\Jairus\OneDrive\Documents\Portfolio\01.Fraud_Detection_Project\models -> True

# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.width", 120)
print("Pandas display options set.")
# Out:
# Pandas display options set.

# %% [markdown]
# # Fraud Detection Project - Data Understanding
#
# ## Objective
# This notebook explores the fraud dataset to understand its structure, inspect data quality, assess class imbalance, and identify initial patterns relevant to fraud detection modeling.

# %% [markdown]
#  # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the dataset

# %%
df = pd.read_csv(r"C:\Users\Jairus\OneDrive\Documents\Portfolio\01.Fraud_Detection_Project\data\raw\creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7        V8        V9       V10       V11  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599  0.098698  0.363787  0.090794 -0.551600
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803  0.085102 -0.255425 -0.166974  1.612727
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461  0.247676 -1.514654  0.207643  0.624501
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609  0.377436 -1.387024 -0.054952 -0.226487
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941 -0.270533  0.817739  0.753074 -0.822843
#
#         V12       V13       V14       V15       V16       V17       V18       V19       V20       V21       V22  \
# 0 -0.617801 -0.991390 -0.311169  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307  0.277838
# ...

# %% [markdown]
# # Dataset Shape

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# # Column names

# %%
df.columns.tolist()
# Out:
# ['Time',
#  'V1',
#  'V2',
#  'V3',
#  'V4',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9',
#  'V10',
#  'V11',
#  'V12',
#  'V13',
#  'V14',
#  'V15',
#  'V16',
#  'V17',
#  'V18',
#  'V19',
#  'V20',
#  'V21',
#  'V22',
#  'V23',
#  'V24',
#  'V25',
#  'V26',
#  'V27',
#  'V28',
#  'Amount',
#  'Class']

# %% [markdown]
# # Data types and non-null counts

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# # Missing values

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# # Duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %% [markdown]
# # Summary statistics

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4            V5            V6  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15  1.021879e-15  1.494498e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00  1.380247e+00  1.332271e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00 -1.137433e+02 -2.616051e+01
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01 -6.915971e-01 -7.682956e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02 -5.433583e-02 -2.741871e-01
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01  6.119264e-01  3.985649e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01  3.480167e+01  7.330163e+01
#
# ...

# %% [markdown]
# # Fraud vs non-fraud counts

# %%
df["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# # Fraud percentage

# %%
class_counts = df["Class"].value_counts()
fraud_pct = (class_counts[1] / len(df)) * 100
nonfraud_pct = (class_counts[0] / len(df)) * 100

print("Non-fraud transactions:", class_counts[0])
print("Fraud transactions:", class_counts[1])
print(f"Non-fraud percentage: {nonfraud_pct:.4f}%")
print(f"Fraud percentage: {fraud_pct:.4f}%")
# Out:
# Non-fraud transactions: 284315
# Fraud transactions: 492
# Non-fraud percentage: 99.8273%
# Fraud percentage: 0.1727%

# %% [markdown]
# # Class distribution plot

# %%
df["Class"].value_counts().plot(kind="bar")
plt.title("Class Distribution (0 = Non-Fraud, 1 = Fraud)")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Amount summary

# %%
df["Amount"].describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# # Amount histogram

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Amount"], bins=50)
plt.title("Transaction Amount Distribution")
plt.xlabel("Amount")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Compare transaction amount by class

# %%
df.groupby("Class")["Amount"].describe()
# Out:
#           count        mean         std  min   25%    50%     75%       max
# Class
# 0      284315.0   88.291022  250.105092  0.0  5.65  22.00   77.05  25691.16
# 1         492.0  122.211321  256.683288  0.0  1.00   9.25  105.89   2125.87

# %% [markdown]
# # Time summary

# %%
df["Time"].describe()
# Out:
# count    284807.000000
# mean      94813.859575
# std       47488.145955
# min           0.000000
# 25%       54201.500000
# 50%       84692.000000
# 75%      139320.500000
# max      172792.000000
# Name: Time, dtype: float64

# %% [markdown]
# # Correlation matrix

# %%
df.corr()
# Out:
#             Time            V1            V2            V3            V4            V5            V6            V7  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01  1.730721e-01 -6.301647e-02  8.471437e-02
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16  1.812612e-17 -6.506567e-16 -1.005191e-15
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15  5.157519e-16  2.787346e-16  2.055934e-16
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16 -6.539009e-17  1.627627e-15  4.895305e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00 -1.719944e-15 -7.491959e-16 -4.104503e-16
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15  1.000000e+00  2.408382e-16  2.715541e-16
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16  2.408382e-16  1.000000e+00  1.191668e-16
# ...

# %% [markdown]
# # Correlation heatmap

# %%
plt.figure(figsize=(12,8))
plt.imshow(df.corr(), aspect="auto")
plt.colorbar()
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# # Fraud vs non-fraud average amount

# %%
df.groupby("Class")["Amount"].mean()
# Out:
# Class
# 0     88.291022
# 1    122.211321
# Name: Amount, dtype: float64

# %% [markdown]
# # Boxplot of Amount by Class

# %%
plt.figure(figsize=(8,5))
df.boxplot(column="Amount", by="Class")
plt.title("Transaction Amount by Class")
plt.suptitle("")
plt.xlabel("Class (0 = Non-Fraud, 1 = Fraud)")
plt.ylabel("Amount")
plt.show()

# %% [markdown]
# ## Initial Findings
#
# ### 1. Dataset size and structure
# The dataset contains 284,807 transactions and 31 columns. The features include `Time`, `Amount`, anonymized PCA-based variables `V1` to `V28`, and the binary target variable `Class`.
#
# ### 2. Severe class imbalance
# Fraud cases are extremely rare in the dataset. There are 284,315 non-fraud transactions and only 492 fraud transactions, meaning fraud represents roughly 0.17% of all observations. This confirms that fraud detection in this dataset is a highly imbalanced classification problem.
#
# ### 3. Data quality
# The dataset does not contain missing values, but it does contain duplicated rows (1,081 duplicates). Duplicate handling will be reviewed in the preprocessing stage before modeling.
#
# ### 4. Transaction amount behavior
# Transaction amounts are highly right-skewed. The median transaction amount is much lower than the maximum transaction amount, indicating that a relatively small number of high-value transactions pull the distribution upward.
#
# ### 5. Fraud vs non-fraud amount comparison
# Fraudulent transactions have a higher average transaction amount than legitimate transactions, but the median fraud amount is lower than the median non-fraud amount. This suggests that fraud does not follow one simple amount pattern and may occur across both small and large transaction values.
#
# ### 6. Modeling implication
# Because fraud is rare, model performance should not be judged by accuracy alone. Later modeling should focus on precision, recall, F1-score, confusion matrix performance, and the ability to identify the fraud class effectively.
